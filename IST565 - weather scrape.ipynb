# %%
#import packages
import urllib2
from bs4 import BeautifulSoup


#create a file to store scraped data
f= open('IST565_weather_final.txt', 'w')

#create function meant to scrape one piece of data for each day from 1/1/12 to 12/31/13
for y in range(2014,2015):
    for m in range(5, 9):
        for d in range(1, 2):
            #check if a leap year
            if y%400 == 0:
                leap = True
            elif y%100 == 0:
                leap = False
            elif y%4 == 0:
                leap = True
            else:
                leap = False
                            
            #check to see if dates have already been scraped	
            
            if (m==2 and leap and d>29):
                continue
            elif (y==2013 and m==2 and d > 28):
                continue
            elif(m in [4, 6, 9, 11] and d > 30):
                continue
            
            

#create timestamp so easy to see where python is status-wise on the scrape
            timestamp = str(y) + str(m) + str(d)
            print 'Getting data for ' + timestamp

#pull URL
            url = 'http://www.wunderground.com/history/airport/KMIC/' + str(y) + '/' + str(m) + '/' + str(d) + '/DailyHistory.html?HideSpecis=1'
            page = urllib2.urlopen(url)
        
        #find the correct piece of data on the page
            soup = BeautifulSoup(page)
            table = soup.find('table', {'class': 'obs-table responsive'})
            #Hour 0
            Date0 = soup.find('h2',{'class': 'history-date'}).string
            Time0 = table.findChildren(['td'])[0].text.strip()
            HourTemp0 = table.findChildren(['td'])[1].text.strip()
            Windchill0 = table.findChildren(['td'])[2].text.strip()
            Humidity0 = table.findChildren(['td'])[4].text.strip()
            Windspeed0 = table.findChildren(['td'])[8].text.strip()
            Conditions0 = table.findChildren(['td'])[12].text.strip()
            
            #Hour 1
            Date1 = soup.find('h2',{'class': 'history-date'}).string
            Time1 = table.findChildren(['td'])[13].text.strip()
            HourTemp1 = table.findChildren(['td'])[14].text.strip()
            Windchill1 = table.findChildren(['td'])[15].text.strip().strip()
            Humidity1 = table.findChildren(['td'])[17].text.strip()
            Windspeed1 = table.findChildren(['td'])[21].text.strip()
            Conditions1 = table.findChildren(['td'])[25].text.strip()
            
            #Hour2
            Date2 = soup.find('h2',{'class': 'history-date'}).string
            Time2 = table.findChildren(['td'])[26].text.strip()
            HourTemp2 = table.findChildren(['td'])[27].text.strip()
            Windchill2 = table.findChildren(['td'])[28].text.strip()
            Humidity2 = table.findChildren(['td'])[30].text.strip()
            Windspeed2 = table.findChildren(['td'])[34].text.strip()
            Conditions2 = table.findChildren(['td'])[38].text.strip()
            
            #Hour3
            Date3 = soup.find('h2',{'class': 'history-date'}).string
            Time3 = table.findChildren(['td'])[39].text.strip()
            HourTemp3 = table.findChildren(['td'])[40].text.strip()
            Windchill3 = table.findChildren(['td'])[41].text.strip()
            Humidity3 = table.findChildren(['td'])[43].text.strip()
            Windspeed3 = table.findChildren(['td'])[47].text.strip()
            Conditions3 = table.findChildren(['td'])[51].text.strip()
            
            #Hour4
            Date4 = soup.find('h2',{'class': 'history-date'}).string
            Time4 = table.findChildren(['td'])[52].text.strip()
            HourTemp4 = table.findChildren(['td'])[53].text.strip()
            Windchill4 = table.findChildren(['td'])[54].text.strip()
            Humidity4 = table.findChildren(['td'])[56].text.strip()
            Windspeed4 = table.findChildren(['td'])[60].text.strip()
            Conditions4 = table.findChildren(['td'])[64].text.strip()
            
            #Hour5
            Date5 = soup.find('h2',{'class': 'history-date'}).string
            Time5 = table.findChildren(['td'])[65].text.strip()
            HourTemp5 = table.findChildren(['td'])[66].text.strip()
            Windchill5 = table.findChildren(['td'])[67].text.strip()
            Humidity5 = table.findChildren(['td'])[69].text.strip()
            Windspeed5 = table.findChildren(['td'])[73].text.strip()
            Conditions5 = table.findChildren(['td'])[77].text.strip()
            
            #Hour6
            Date6 = soup.find('h2',{'class': 'history-date'}).string
            Time6 = table.findChildren(['td'])[78].text.strip()
            HourTemp6 = table.findChildren(['td'])[79].text.strip()
            Windchill6 = table.findChildren(['td'])[80].text.strip()
            Humidity6 = table.findChildren(['td'])[82].text.strip()
            Windspeed6 = table.findChildren(['td'])[86].text.strip()
            Conditions6 = table.findChildren(['td'])[90].text.strip()
            
            #Hour7
            Date7 = soup.find('h2',{'class': 'history-date'}).string
            Time7 = table.findChildren(['td'])[91].text.strip()
            HourTemp7 = table.findChildren(['td'])[92].text.strip()
            Windchill7 = table.findChildren(['td'])[93].text.strip()
            Humidity7 = table.findChildren(['td'])[95].text.strip()
            Windspeed7 = table.findChildren(['td'])[99].text.strip()
            Conditions7 = table.findChildren(['td'])[103].text.strip()
            
            #Hour8
            Date8 = soup.find('h2',{'class': 'history-date'}).string
            Time8 = table.findChildren(['td'])[104].text.strip()
            HourTemp8 = table.findChildren(['td'])[105].text.strip()
            Windchill8 = table.findChildren(['td'])[106].text.strip()
            Humidity8 = table.findChildren(['td'])[108].text.strip()
            Windspeed8 = table.findChildren(['td'])[112].text.strip()
            Conditions8 = table.findChildren(['td'])[116].text.strip()
            
            #Hour9
            Date9 = soup.find('h2',{'class': 'history-date'}).string
            Time9 = table.findChildren(['td'])[117].text.strip()
            HourTemp9 = table.findChildren(['td'])[118].text.strip()
            Windchill9 = table.findChildren(['td'])[119].text.strip()
            Humidity9 = table.findChildren(['td'])[121].text.strip()
            Windspeed9 = table.findChildren(['td'])[125].text.strip()
            Conditions9 = table.findChildren(['td'])[129].text.strip()
            
            #Hour10
            Date10 = soup.find('h2',{'class': 'history-date'}).string
            Time10 = table.findChildren(['td'])[130].text.strip()
            HourTemp10 = table.findChildren(['td'])[131].text.strip()
            Windchill10 = table.findChildren(['td'])[132].text.strip()
            Humidity10 = table.findChildren(['td'])[134].text.strip()
            Windspeed10 = table.findChildren(['td'])[138].text.strip()
            Conditions10 = table.findChildren(['td'])[142].text.strip()
            
            #Hour11
            Date11 = soup.find('h2',{'class': 'history-date'}).string
            Time11 = table.findChildren(['td'])[143].text.strip()
            HourTemp11 = table.findChildren(['td'])[144].text.strip()
            Windchill11 = table.findChildren(['td'])[145].text.strip()
            Humidity11 = table.findChildren(['td'])[147].text.strip()
            Windspeed11 = table.findChildren(['td'])[151].text.strip()
            Conditions11 = table.findChildren(['td'])[155].text.strip()
            
            #Hour12
            Date12 = soup.find('h2',{'class': 'history-date'}).string
            Time12 = table.findChildren(['td'])[156].text.strip()
            HourTemp12 = table.findChildren(['td'])[157].text.strip()
            Windchill12 = table.findChildren(['td'])[158].text.strip()
            Humidity12 = table.findChildren(['td'])[160].text.strip()
            Windspeed12 = table.findChildren(['td'])[164].text.strip()
            Conditions12 = table.findChildren(['td'])[168].text.strip()
            
            #Hour13
            Date13 = soup.find('h2',{'class': 'history-date'}).string
            Time13 = table.findChildren(['td'])[169].text.strip()
            HourTemp13 = table.findChildren(['td'])[170].text.strip()
            Windchill13 = table.findChildren(['td'])[171].text.strip()
            Humidity13 = table.findChildren(['td'])[173].text.strip()
            Windspeed13 = table.findChildren(['td'])[177].text.strip()
            Conditions13 = table.findChildren(['td'])[181].text.strip()
            
            #Hour14
            Date14 = soup.find('h2',{'class': 'history-date'}).string
            Time14 = table.findChildren(['td'])[182].text.strip()
            HourTemp14 = table.findChildren(['td'])[183].text.strip()
            Windchill14 = table.findChildren(['td'])[184].text.strip()
            Humidity14 = table.findChildren(['td'])[186].text.strip()
            Windspeed14 = table.findChildren(['td'])[190].text.strip()
            Conditions14 = table.findChildren(['td'])[194].text.strip()
            
            #Hour15
            Date15 = soup.find('h2',{'class': 'history-date'}).string
            Time15 = table.findChildren(['td'])[195].text.strip()
            HourTemp15 = table.findChildren(['td'])[196].text.strip()
            Windchill15 = table.findChildren(['td'])[197].text.strip()
            Humidity15 = table.findChildren(['td'])[199].text.strip()
            Windspeed15 = table.findChildren(['td'])[203].text.strip()
            Conditions15 = table.findChildren(['td'])[207].text.strip()
            
            #Hour16
            Date16 = soup.find('h2',{'class': 'history-date'}).string
            Time16 = table.findChildren(['td'])[208].text.strip()
            HourTemp16 = table.findChildren(['td'])[209].text.strip()
            Windchill16 = table.findChildren(['td'])[210].text.strip()
            Humidity16 = table.findChildren(['td'])[212].text.strip()
            Windspeed16 = table.findChildren(['td'])[216].text.strip()
            Conditions16 = table.findChildren(['td'])[220].text.strip()
            
            #Hour17
            Date17 = soup.find('h2',{'class': 'history-date'}).string
            Time17 = table.findChildren(['td'])[221].text.strip()
            HourTemp17 = table.findChildren(['td'])[222].text.strip()
            Windchill17 = table.findChildren(['td'])[223].text.strip()
            Humidity17 = table.findChildren(['td'])[225].text.strip()
            Windspeed17 = table.findChildren(['td'])[229].text.strip()
            Conditions17 = table.findChildren(['td'])[233].text.strip()
            
            #Hour18
            Date18 = soup.find('h2',{'class': 'history-date'}).string
            Time18 = table.findChildren(['td'])[234].text.strip()
            HourTemp18 = table.findChildren(['td'])[235].text.strip()
            Windchill18 = table.findChildren(['td'])[236].text.strip()
            Humidity18 = table.findChildren(['td'])[238].text.strip()
            Windspeed18 = table.findChildren(['td'])[242].text.strip()
            Conditions18 = table.findChildren(['td'])[246].text.strip()
            
            #Hour19
            Date19 = soup.find('h2',{'class': 'history-date'}).string
            Time19 = table.findChildren(['td'])[247].text.strip()
            HourTemp19 = table.findChildren(['td'])[248].text.strip()
            Windchill19 = table.findChildren(['td'])[249].text.strip()
            Humidity19 = table.findChildren(['td'])[251].text.strip()
            Windspeed19 = table.findChildren(['td'])[255].text.strip()
            Conditions19 = table.findChildren(['td'])[259].text.strip()
            
            #Hour20
            Date20 = soup.find('h2',{'class': 'history-date'}).string
            Time20 = table.findChildren(['td'])[260].text.strip()
            HourTemp20 = table.findChildren(['td'])[261].text.strip()
            Windchill20 = table.findChildren(['td'])[262].text.strip()
            Humidity20 = table.findChildren(['td'])[264].text.strip()
            Windspeed20 = table.findChildren(['td'])[268].text.strip()
            Conditions20 = table.findChildren(['td'])[272].text.strip()
            
            #Hour21
            Date21 = soup.find('h2',{'class': 'history-date'}).string
            Time21 = table.findChildren(['td'])[273].text.strip()
            HourTemp21 = table.findChildren(['td'])[274].text.strip()
            Windchill21 = table.findChildren(['td'])[275].text.strip()
            Humidity21 = table.findChildren(['td'])[277].text.strip()
            Windspeed21 = table.findChildren(['td'])[281].text.strip()
            Conditions21 = table.findChildren(['td'])[285].text.strip()
            if IndexError:
                continue
            
            #Hour22
            Date22 = soup.find('h2',{'class': 'history-date'}).string
            Time22 = table.findChildren(['td'])[286].text.strip()
            HourTemp22 = table.findChildren(['td'])[287].text.strip()
            Windchill22 = table.findChildren(['td'])[288].text.strip()
            Humidity22 = table.findChildren(['td'])[290].text.strip()
            Windspeed22 = table.findChildren(['td'])[294].text.strip()
            Conditions22 = table.findChildren(['td'])[298].text.strip()
            if IndexError:
                continue
            
            #Hour23
            Date23 = soup.find('h2',{'class': 'history-date'}).string
            Time23 = table.findChildren(['td'])[299].text.strip()
            HourTemp23 = table.findChildren(['td'])[300].text.strip()
            Windchill23 = table.findChildren(['td'])[301].text.strip()
            Humidity23 = table.findChildren(['td'])[303].text.strip()
            Windspeed23 = table.findChildren(['td'])[307].text.strip()
            Conditions23 = table.findChildren(['td'])[311].text.strip()
            if IndexError:
                continue
            
            x = Date0 + "|" + Time0 + "|" + HourTemp0 + "|" + Windchill0 + "|" + Humidity0 + "|" + Windspeed0 + "|" + Conditions0 + "\n" #+ Date1 + "|" + Time1 + "|" + HourTemp1 + "|" + Windchill1 + "|" + Humidity1 + "|" + Windspeed1 + "|" + Conditions1 + "\n" + Date2 + "|" + Time2 + "|" + HourTemp2 + "|" + Windchill2 + "|" + Humidity2 + "|" + Windspeed2 + "|" + Conditions2 + "\n" + Date3 + "|" + Time3 + "|" + HourTemp3 + "|" + Windchill3 + "|" + Humidity3 + "|" + Windspeed3 + "|" + Conditions3 + "\n" + Date4 + "|" + Time4 + "|" + HourTemp4 + "|" + Windchill4 + "|" + Humidity4 + "|" + Windspeed4 + "|" + Conditions4 + "\n" + Date5 + "|" + Time5 + "|" + HourTemp5 + "|" + Windchill5 + "|" + Humidity5 + "|" + Windspeed5 + "|" + Conditions5 + "\n" +Date6 + "|" + Time6 + "|" + HourTemp6 + "|" + Windchill6 + "|" + Humidity6 + "|" + Windspeed6 + "|" + Conditions6 + "\n" + Date7 + "|" + Time7 + "|" + HourTemp7 + "|" + Windchill7 + "|" + Humidity7 + "|" + Windspeed7 + "|" + Conditions7 + "\n" + Date8 + "|" + Time8 + "|" + HourTemp8 + "|" + Windchill8 + "|" + Humidity8 + "|" + Windspeed8 + "|" + Conditions8 + "\n" + Date9 + "|" + Time9 + "|" + HourTemp9 + "|" + Windchill9 + "|" + Humidity9 + "|" + Windspeed9 + "|" + Conditions9 + "\n" + Date10 + "|" + Time10 + "|" + HourTemp10 + "|" + Windchill10 + "|" + Humidity10 + "|" + Windspeed10 + "|" + Conditions10 + "\n" + Date11 + "|" + Time11 + "|" + HourTemp11 + "|" + Windchill11 + "|" + Humidity11 + "|" + Windspeed11 + "|" + Conditions11 + "\n" + Date12 + "|" + Time12 + "|" + HourTemp12 + "|" + Windchill12 + "|" + Humidity12 + "|" + Windspeed12 + "|" + Conditions12 + "\n" + Date13 + "|" + Time13 + "|" + HourTemp13 + "|" + Windchill13 + "|" + Humidity13 + "|" + Windspeed13 + "|" + Conditions13 + "\n" + Date14 + "|" + Time14 + "|" + HourTemp14 + "|" + Windchill14 + "|" + Humidity14 + "|" + Windspeed14 + "|" + Conditions14 + "\n" + Date15 + "|" + Time15 + "|" + HourTemp15 + "|" + Windchill15 + "|" + Humidity15 + "|" + Windspeed15 + "|" + Conditions15 + "\n" + Date16 + "|" + Time16 + "|" + HourTemp16 + "|" + Windchill16 + "|" + Humidity16 + "|" + Windspeed16 + "|" + Conditions16 + "\n" + Date17 + "|" + Time17 + "|" + HourTemp17 + "|" + Windchill17 + "|" + Humidity17 + "|" + Windspeed17 + "|" + Conditions17 + "\n" + Date18 + "|" + Time18 + "|" + HourTemp18 + "|" + Windchill18 + "|" + Humidity18 + "|" + Windspeed18 + "|" + Conditions18 + "\n" + Date19 + "|" + Time19 + "|" + HourTemp19 + "|" + Windchill19 + "|" + Humidity19 + "|" + Windspeed19 + "|" + Conditions19 + "\n" + Date20 + "|" + Time20 + "|" + HourTemp20 + "|" + Windchill20 + "|" + Humidity20 + "|" + Windspeed20 + "|" + Conditions20 + "\n" + Date21 + "|" + Time21 + "|" + HourTemp21 + "|" + Windchill21 + "|" + Humidity21 + "|" + Windspeed21 + "|" + Conditions21 + "\n" + Date22 + "|" + Time22 + "|" + HourTemp22 + "|" + Windchill22 + "|" + Humidity22 + "|" + Windspeed22 + "|" + Conditions22 + "\n" + Date23 + "|" + Time23 + "|" + HourTemp23 + "|" + Windchill23 + "|" + Humidity23 + "|" + Windspeed23 + "|" + Conditions23 + "\n"
            x = x.encode('ascii', 'ignore').decode('ascii')
    
            for s in x:
                f.write(s)
# Out:
# Getting data for 201451
# Getting data for 201461
# Getting data for 201471
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-de60f96d59ce> in <module>()
#     237             HourTemp21 = table.findChildren(['td'])[274].text.strip()
#     238             Windchill21 = table.findChildren(['td'])[275].text.strip()
# --> 239             Humidity21 = table.findChildren(['td'])[277].text.strip()
#     240             Windspeed21 = table.findChildren(['td'])[281].text.strip()
#     241             Conditions21 = table.findChildren(['td'])[285].text.strip()
#
# IndexError: list index out of range

# %%
import urllib2, re, time
# importing parser
from bs4 import BeautifulSoup
f = open('weathertest.txt', 'w')
# Start and end year of simulation
for y in range(2014, 2015):
    # Type the months that you want to extract
# For example for January and February use range(1,3)
    for m in range(11, 12):
#checking for leap years
        for d in range(1,3):
            if y%400 == 0:
                leap = True
            elif y%100 == 0:
                leap = False
            elif y%4 == 0:
                leap = True
            else:
                leap = False
            if (m == 2 and leap and d > 29):
                continue
            elif (m == 2 and d > 28):
                continue
            elif (m in [4, 6, 9, 10] and d > 30):
                continue

            url = "http://www.wunderground.com/history/airport/KSYR/" + str(y) + "/" + str(m) + "/" + str(d) + "/DailyHistory.html"
            page = urllib2.urlopen(url)

            #opening the website with Beautiful Soup
            soup = BeautifulSoup(page)

            # finding section with observation details
            paragList = soup.findAll(id="observations_details")
            counter = 0
            counter_max = 0     # maximum number of columns

            # adding a zero to one digit numbers
            string = ''
            if len(str(m)) < 2:
                mStamp = '0' + str(m)
            else:
                mStamp = str(m)
            if len(str(d)) < 2:
                dStamp = '0' + str(d)
            else:
                dStamp = str(d)

            # time stamp is four digit year, two digit month, and two digit day    
            timestamp = str(y) + mStamp + dStamp
            print(timestamp)

            for i in paragList:

                # writing in text file the header with the name of each column
                headList = i.findAll('th')
                f.write('DATE,')
                for k in headList:
                    h_element = k.text
                    s = str(h_element)
                    f.write(s)
                    f.write(',')
                    counter_max = counter_max + 1
                f.write(' \n')

                # writing in text file each row with data
                tableList = i.findAll('tbody')
                for l in tableList:
                    bodyList = l.findAll('td')
                    for j in bodyList:
                        if counter == 0:
                            f.write(timestamp + ',')
                        if j.string:
                            element = j.text
                            # print (element)
                            s = str(element)
                            s = s.encode('ascii', 'ignore').decode('ascii')
                            f.write(s)
                            f.write(',')
                        else:
                            elementList = j.findAll(j.b) + j.findAll('b')
                            for k in elementList:
                                if k.string:
                                    element = k.text
                                    # print(element)
                                    s = str(element)
                                    f.write(s)
                                    f.write(',')
                        counter = counter + 1
                        if counter == counter_max:
                            # print
                            # print("************************")
                            # print("**** NEXT RECORD *******")
                            # print("**** *******************")
                            f.write('\n')
                            counter = 0
            # print ("\n")
            # print("**** NEXT YEAR *******")


f.close()
